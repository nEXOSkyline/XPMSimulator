# %% [markdown]
# <a href="https://colab.research.google.com/github/nEXOSkyline/XPMSimulator/blob/main/pyROOTsetup.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !apt-get install libpython3.6-dev
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# E: Unable to locate package libpython3.6-dev
# E: Couldn't find any package by glob 'libpython3.6-dev'
# E: Couldn't find any package by regex 'libpython3.6-dev'

# %%
# !wget https://www.bunsutechnologies.com/rootWithPython310.tar.gz
# !tar -zxvf rootWithPython310.tar.gz
# !apt-get install git dpkg-dev cmake g++ gcc binutils libx11-dev libxpm-dev libxft-dev libxext-dev tar gfortran subversion libpython3.10-dev
import sys
sys.path.append("/content/rootWithPython310/root_build/")
sys.path.append("/content/rootWithPython310/bin/")
sys.path.append("/content/rootWithPython310/include/")
sys.path.append("/content/rootWithPython310/lib/")
import ctypes
ctypes.cdll.LoadLibrary('/content/rootWithPython310/lib/libCore.so')
ctypes.cdll.LoadLibrary('/content/rootWithPython310/lib/libThread.so')
ctypes.cdll.LoadLibrary('/content/rootWithPython310/lib/libTreePlayer.so')
import ROOT
# Out:
# Streaming output truncated to the last 5000 lines.
# rootWithPython310/root/ui5/distribution/resources/sap/tnt/themes/base/illustrations/tnt-Dialog-Lock.svg
# rootWithPython310/root/ui5/distribution/resources/sap/tnt/themes/base/illustrations/tnt-Scene-CodePlaceholder.svg
# rootWithPython310/root/ui5/distribution/resources/sap/tnt/themes/base/illustrations/tnt-Dialog-NoFlows.svg
# rootWithPython310/root/ui5/distribution/resources/sap/tnt/themes/base/illustrations/tnt-Dialog-NoUsers.svg
# rootWithPython310/root/ui5/distribution/resources/sap/tnt/themes/base/illustrations/tnt-Scene-Company.svg
# rootWithPython310/root/ui5/distribution/resources/sap/tnt/themes/base/illustrations/tnt-Scene-Radar.svg
# rootWithPython310/root/ui5/distribution/resources/sap/tnt/themes/base/illustrations/tnt-Spot-Fingerprint.svg
# rootWithPython310/root/ui5/distribution/resources/sap/tnt/themes/base/illustrations/tnt-Scene-UnsuccessfulAuth.svg
# rootWithPython310/root/ui5/distribution/resources/sap/tnt/themes/base/illustrations/tnt-Dialog-Company.svg
# rootWithPython310/root/ui5/distribution/resources/sap/tnt/themes/base/illustrations/tnt-Dialog-Fingerprint.svg
# rootWithPython310/root/ui5/distribution/resources/sap/tnt/themes/base/illustrations/tnt-Dialog-SessionExpired.svg
# rootWithPython310/root/ui5/distribution/resources/sap/tnt/themes/base/illustrations/tnt-Dialog-UnsuccessfulAuth.svg
# rootWithPython310/root/ui5/distribution/resources/sap/tnt/themes/base/illustrations/tnt-Scene-Fingerprint.svg
# rootWithPython310/root/ui5/distribution/resources/sap/tnt/themes/base/illustrations/tnt-Scene-FaceID.svg
# rootWithPython310/root/ui5/distribution/resources/sap/tnt/themes/base/illustrations/tnt-Dialog-Services.svg
# rootWithPython310/root/ui5/distribution/resources/sap/tnt/themes/base/illustrations/tnt-Scene-Services.svg
# rootWithPython310/root/ui5/distribution/resources/sap/tnt/themes/base/illustrations/tnt-Spot-Radar.svg
# rootWithPython310/root/ui5/distribution/resources/sap/tnt/themes/base/illustrations/tnt-Scene-SessionExpiring.svg
# rootWithPython310/root/ui5/distribution/resources/sap/tnt/themes/base/illustrations/tnt-Scene-NoFlows.svg
# rootWithPython310/root/ui5/distribution/resources/sap/tnt/themes/base/illustrations/tnt-Spot-SessionExpired.svg
# rootWithPython310/root/ui5/distribution/resources/sap/tnt/themes/base/illustrations/tnt-Scene-NoUsers.svg
# rootWithPython310/root/ui5/distribution/resources/sap/tnt/themes/base/illustrations/tnt-Dialog-ExternalLink.svg
# rootWithPython310/root/ui5/distribution/resources/sap/tnt/themes/base/illustrations/tnt-Scene-Unlock.svg
# rootWithPython310/root/ui5/distribution/resources/sap/tnt/themes/base/illustrations/tnt-Scene-NoApplications.svg
# rootWithPython310/root/ui5/distribution/resources/sap/tnt/themes/base/illustrations/tnt-Dialog-SessionExpiring.svg
# rootWithPython310/root/ui5/distribution/resources/sap/tnt/themes/base/illustrations/metadata.json
# rootWithPython310/root/ui5/distribution/resources/sap/tnt/themes/base/illustrations/tnt-Spot-FaceID.svg
# rootWithPython310/root/ui5/distribution/resources/sap/tnt/themes/base/illustrations/tnt-Spot-Services.svg
# rootWithPython310/root/ui5/distribution/resources/sap/tnt/themes/base/illustrations/tnt-Spot-NoFlows.svg
# rootWithPython310/root/ui5/distribution/resources/sap/tnt/themes/base/illustrations/tnt-Spot-ExternalLink.svg
# rootWithPython310/root/ui5/distribution/resources/sap/tnt/themes/base/illustrations/tnt-Spot-SuccessfulAuth.svg
# rootWithPython310/root/ui5/distribution/resources/sap/tnt/themes/base/illustrations/tnt-Spot-NoUsers.svg
# rootWithPython310/root/ui5/distribution/resources/sap/tnt/themes/base/illustrations/tnt-Dialog-CodePlaceholder.svg
# rootWithPython310/root/ui5/distribution/resources/sap/tnt/themes/base/illustrations/tnt-Spot-Lock.svg
# rootWithPython310/root/ui5/distribution/resources/sap/tnt/themes/base/illustrations/tnt-Dialog-FaceID.svg
# rootWithPython310/root/ui5/distribution/resources/sap/tnt/themes/base/illustrations/tnt-Dialog-Unlock.svg
# rootWithPython310/root/ui5/distribution/resources/sap/tnt/themes/base/illustrations/tnt-Dialog-Mission.svg
# rootWithPython310/root/ui5/distribution/resources/sap/tnt/themes/base/illustrations/tnt-Scene-Mission.svg
# rootWithPython310/root/ui5/distribution/resources/sap/tnt/themes/base/illustrations/tnt-Spot-NoApplications.svg
# rootWithPython310/root/ui5/distribution/resources/sap/tnt/themes/base/illustrations/tnt-Spot-CodePlaceholder.svg
# rootWithPython310/root/ui5/distribution/resources/sap/tnt/themes/base/illustrations/tnt-Scene-ExternalLink.svg
# rootWithPython310/root/ui5/distribution/resources/sap/tnt/themes/base/illustrations/tnt-Spot-SessionExpiring.svg
# rootWithPython310/root/ui5/distribution/resources/sap/tnt/themes/base/illustrations/tnt-Spot-UnsuccessfulAuth.svg
# rootWithPython310/root/ui5/distribution/resources/sap/tnt/themes/sap_belize/
# rootWithPython310/root/ui5/distribution/resources/sap/tnt/themes/sap_belize/.theming
# rootWithPython310/root/ui5/distribution/resources/sap/tnt/themes/sap_belize/css_variables.less
# rootWithPython310/root/ui5/distribution/resources/sap/tnt/themes/sap_belize/css_variables.css
# rootWithPython310/root/ui5/distribution/resources/sap/tnt/themes/sap_belize/library-RTL.css
# rootWithPython310/root/ui5/distribution/resources/sap/tnt/themes/sap_belize/library_skeleton.css
# rootWithPython310/root/ui5/distribution/resources/sap/tnt/themes/sap_belize/library.css
# rootWithPython310/root/ui5/distribution/resources/sap/tnt/themes/sap_belize/library.less
# rootWithPython310/root/ui5/distribution/resources/sap/tnt/themes/sap_belize/resources.json
# rootWithPython310/root/ui5/distribution/resources/sap/tnt/themes/sap_belize/library.source.less
# rootWithPython310/root/ui5/distribution/resources/sap/tnt/themes/sap_belize/global.less
# rootWithPython310/root/ui5/distribution/resources/sap/tnt/themes/sap_belize/css_variables.source.less
# rootWithPython310/root/ui5/distribution/resources/sap/tnt/themes/sap_belize/library-parameters.json
# rootWithPython310/root/ui5/distribution/resources/sap/tnt/themes/sap_belize/library_skeleton-RTL.css
# rootWithPython310/root/ui5/distribution/resources/sap/tnt/themes/sap_fiori_3/
# rootWithPython310/root/ui5/distribution/resources/sap/tnt/themes/sap_fiori_3/.theming
# rootWithPython310/root/ui5/distribution/resources/sap/tnt/themes/sap_fiori_3/css_variables.less
# rootWithPython310/root/ui5/distribution/resources/sap/tnt/themes/sap_fiori_3/css_variables.css
# rootWithPython310/root/ui5/distribution/resources/sap/tnt/themes/sap_fiori_3/library-RTL.css
# rootWithPython310/root/ui5/distribution/resources/sap/tnt/themes/sap_fiori_3/library_skeleton.css
# rootWithPython310/root/ui5/distribution/resources/sap/tnt/themes/sap_fiori_3/library.css
# rootWithPython310/root/ui5/distribution/resources/sap/tnt/themes/sap_fiori_3/library.less
# rootWithPython310/root/ui5/distribution/resources/sap/tnt/themes/sap_fiori_3/resources.json
# rootWithPython310/root/ui5/distribution/resources/sap/tnt/themes/sap_fiori_3/library.source.less
# rootWithPython310/root/ui5/distribution/resources/sap/tnt/themes/sap_fiori_3/css_variables.source.less
# rootWithPython310/root/ui5/distribution/resources/sap/tnt/themes/sap_fiori_3/library-parameters.json
# rootWithPython310/root/ui5/distribution/resources/sap/tnt/themes/sap_fiori_3/library_skeleton-RTL.css
# rootWithPython310/root/ui5/distribution/resources/sap/tnt/messagebundle_en.properties
# rootWithPython310/root/ui5/distribution/resources/sap/tnt/library.js
# rootWithPython310/root/ui5/distribution/resources/sap/tnt/messagebundle.properties
# rootWithPython310/root/ui5/distribution/resources/sap/f/
# rootWithPython310/root/ui5/distribution/resources/sap/f/library-preload.js
# rootWithPython310/root/ui5/distribution/resources/sap/f/library-preload.js.map
# rootWithPython310/root/ui5/distribution/resources/sap/f/themes/
# rootWithPython310/root/ui5/distribution/resources/sap/f/themes/base/
# rootWithPython310/root/ui5/distribution/resources/sap/f/themes/base/.theming
# rootWithPython310/root/ui5/distribution/resources/sap/f/themes/base/css_variables.less
# rootWithPython310/root/ui5/distribution/resources/sap/f/themes/base/css_variables.css
# rootWithPython310/root/ui5/distribution/resources/sap/f/themes/base/library-RTL.css
# rootWithPython310/root/ui5/distribution/resources/sap/f/themes/base/library_skeleton.css
# rootWithPython310/root/ui5/distribution/resources/sap/f/themes/base/library.css
# rootWithPython310/root/ui5/distribution/resources/sap/f/themes/base/library.less
# rootWithPython310/root/ui5/distribution/resources/sap/f/themes/base/resources.json
# rootWithPython310/root/ui5/distribution/resources/sap/f/themes/base/library.source.less
# rootWithPython310/root/ui5/distribution/resources/sap/f/themes/base/css_variables.source.less
# rootWithPython310/root/ui5/distribution/resources/sap/f/themes/base/library-parameters.json
# rootWithPython310/root/ui5/distribution/resources/sap/f/themes/base/library_skeleton-RTL.css
# rootWithPython310/root/ui5/distribution/resources/sap/f/themes/sap_belize/
# rootWithPython310/root/ui5/distribution/resources/sap/f/themes/sap_belize/.theming
# rootWithPython310/root/ui5/distribution/resources/sap/f/themes/sap_belize/css_variables.less
# rootWithPython310/root/ui5/distribution/resources/sap/f/themes/sap_belize/css_variables.css
# rootWithPython310/root/ui5/distribution/resources/sap/f/themes/sap_belize/library-RTL.css
# rootWithPython310/root/ui5/distribution/resources/sap/f/themes/sap_belize/library_skeleton.css
# rootWithPython310/root/ui5/distribution/resources/sap/f/themes/sap_belize/library.css
# rootWithPython310/root/ui5/distribution/resources/sap/f/themes/sap_belize/library.less
# rootWithPython310/root/ui5/distribution/resources/sap/f/themes/sap_belize/resources.json
# rootWithPython310/root/ui5/distribution/resources/sap/f/themes/sap_belize/library.source.less
# rootWithPython310/root/ui5/distribution/resources/sap/f/themes/sap_belize/css_variables.source.less
# rootWithPython310/root/ui5/distribution/resources/sap/f/themes/sap_belize/library-parameters.json
# rootWithPython310/root/ui5/distribution/resources/sap/f/themes/sap_belize/library_skeleton-RTL.css
# rootWithPython310/root/ui5/distribution/resources/sap/f/themes/sap_fiori_3/
# rootWithPython310/root/ui5/distribution/resources/sap/f/themes/sap_fiori_3/.theming
# rootWithPython310/root/ui5/distribution/resources/sap/f/themes/sap_fiori_3/css_variables.less
# rootWithPython310/root/ui5/distribution/resources/sap/f/themes/sap_fiori_3/css_variables.css
# rootWithPython310/root/ui5/distribution/resources/sap/f/themes/sap_fiori_3/library-RTL.css
# rootWithPython310/root/ui5/distribution/resources/sap/f/themes/sap_fiori_3/library_skeleton.css
# rootWithPython310/root/ui5/distribution/resources/sap/f/themes/sap_fiori_3/library.css
# rootWithPython310/root/ui5/distribution/resources/sap/f/themes/sap_fiori_3/library.less
# rootWithPython310/root/ui5/distribution/resources/sap/f/themes/sap_fiori_3/resources.json
# rootWithPython310/root/ui5/distribution/resources/sap/f/themes/sap_fiori_3/library.source.less
# rootWithPython310/root/ui5/distribution/resources/sap/f/themes/sap_fiori_3/css_variables.source.less
# rootWithPython310/root/ui5/distribution/resources/sap/f/themes/sap_fiori_3/library-parameters.json
# rootWithPython310/root/ui5/distribution/resources/sap/f/themes/sap_fiori_3/library_skeleton-RTL.css
# rootWithPython310/root/ui5/distribution/resources/sap/f/messagebundle_en.properties
# rootWithPython310/root/ui5/distribution/resources/sap/f/library.js
# rootWithPython310/root/ui5/distribution/resources/sap/f/messagebundle.properties
# rootWithPython310/root/ui5/distribution/resources/sap/uxap/
# rootWithPython310/root/ui5/distribution/resources/sap/uxap/library-preload.js
# rootWithPython310/root/ui5/distribution/resources/sap/uxap/library-preload.js.map
# rootWithPython310/root/ui5/distribution/resources/sap/uxap/themes/
# rootWithPython310/root/ui5/distribution/resources/sap/uxap/themes/base/
# rootWithPython310/root/ui5/distribution/resources/sap/uxap/themes/base/.theming
# rootWithPython310/root/ui5/distribution/resources/sap/uxap/themes/base/css_variables.less
# rootWithPython310/root/ui5/distribution/resources/sap/uxap/themes/base/css_variables.css
# rootWithPython310/root/ui5/distribution/resources/sap/uxap/themes/base/library-RTL.css
# rootWithPython310/root/ui5/distribution/resources/sap/uxap/themes/base/library_skeleton.css
# rootWithPython310/root/ui5/distribution/resources/sap/uxap/themes/base/library.css
# rootWithPython310/root/ui5/distribution/resources/sap/uxap/themes/base/library.less
# rootWithPython310/root/ui5/distribution/resources/sap/uxap/themes/base/resources.json
# rootWithPython310/root/ui5/distribution/resources/sap/uxap/themes/base/library.source.less
# rootWithPython310/root/ui5/distribution/resources/sap/uxap/themes/base/css_variables.source.less
# rootWithPython310/root/ui5/distribution/resources/sap/uxap/themes/base/library-parameters.json
# rootWithPython310/root/ui5/distribution/resources/sap/uxap/themes/base/library_skeleton-RTL.css
# rootWithPython310/root/ui5/distribution/resources/sap/uxap/themes/sap_belize/
# rootWithPython310/root/ui5/distribution/resources/sap/uxap/themes/sap_belize/.theming
# rootWithPython310/root/ui5/distribution/resources/sap/uxap/themes/sap_belize/css_variables.less
# rootWithPython310/root/ui5/distribution/resources/sap/uxap/themes/sap_belize/css_variables.css
# rootWithPython310/root/ui5/distribution/resources/sap/uxap/themes/sap_belize/library-RTL.css
# rootWithPython310/root/ui5/distribution/resources/sap/uxap/themes/sap_belize/library_skeleton.css
# rootWithPython310/root/ui5/distribution/resources/sap/uxap/themes/sap_belize/library.css
# rootWithPython310/root/ui5/distribution/resources/sap/uxap/themes/sap_belize/library.less
# rootWithPython310/root/ui5/distribution/resources/sap/uxap/themes/sap_belize/resources.json
# rootWithPython310/root/ui5/distribution/resources/sap/uxap/themes/sap_belize/library.source.less
# rootWithPython310/root/ui5/distribution/resources/sap/uxap/themes/sap_belize/css_variables.source.less
# rootWithPython310/root/ui5/distribution/resources/sap/uxap/themes/sap_belize/library-parameters.json
# rootWithPython310/root/ui5/distribution/resources/sap/uxap/themes/sap_belize/library_skeleton-RTL.css
# rootWithPython310/root/ui5/distribution/resources/sap/uxap/themes/sap_fiori_3/
# rootWithPython310/root/ui5/distribution/resources/sap/uxap/themes/sap_fiori_3/.theming
# rootWithPython310/root/ui5/distribution/resources/sap/uxap/themes/sap_fiori_3/css_variables.less
# rootWithPython310/root/ui5/distribution/resources/sap/uxap/themes/sap_fiori_3/css_variables.css
# rootWithPython310/root/ui5/distribution/resources/sap/uxap/themes/sap_fiori_3/library-RTL.css
# rootWithPython310/root/ui5/distribution/resources/sap/uxap/themes/sap_fiori_3/library_skeleton.css
# rootWithPython310/root/ui5/distribution/resources/sap/uxap/themes/sap_fiori_3/library.css
# rootWithPython310/root/ui5/distribution/resources/sap/uxap/themes/sap_fiori_3/library.less
# rootWithPython310/root/ui5/distribution/resources/sap/uxap/themes/sap_fiori_3/resources.json
# rootWithPython310/root/ui5/distribution/resources/sap/uxap/themes/sap_fiori_3/library.source.less
# rootWithPython310/root/ui5/distribution/resources/sap/uxap/themes/sap_fiori_3/css_variables.source.less
# rootWithPython310/root/ui5/distribution/resources/sap/uxap/themes/sap_fiori_3/library-parameters.json
# rootWithPython310/root/ui5/distribution/resources/sap/uxap/themes/sap_fiori_3/library_skeleton-RTL.css
# rootWithPython310/root/ui5/distribution/resources/sap/uxap/messagebundle_en.properties
# rootWithPython310/root/ui5/distribution/resources/sap/uxap/library.js
# rootWithPython310/root/ui5/distribution/resources/sap/uxap/messagebundle.properties
# rootWithPython310/root/ui5/distribution/resources/sap-ui-core.js.map
# rootWithPython310/root/ui5/distribution/resources/sap-ui-core.js
# rootWithPython310/root/ui5/distribution/NOTICE.txt
# rootWithPython310/root/ui5/distribution/README.txt
# rootWithPython310/root/ui5/distribution/LICENSE.txt
# rootWithPython310/root/ui5/distribution/THIRDPARTY.txt
# rootWithPython310/root/ui5/panel/
# rootWithPython310/root/ui5/panel/panel.html
# rootWithPython310/root/ui5/panel/Controller.js
# rootWithPython310/root/ui5/browser/
# rootWithPython310/root/ui5/browser/style.css
# rootWithPython310/root/ui5/browser/browser.html
# rootWithPython310/root/ui5/browser/controller/
# rootWithPython310/root/ui5/browser/controller/Browser.controller.js
# rootWithPython310/root/ui5/browser/controller/FileDialog.controller.js
# rootWithPython310/root/ui5/browser/logo.png
# rootWithPython310/root/ui5/browser/manifest.json
# rootWithPython310/root/ui5/browser/view/
# rootWithPython310/root/ui5/browser/view/Browser.view.xml
# rootWithPython310/root/ui5/browser/view/FileDialog.view.xml
# rootWithPython310/root/ui5/browser/view/filedialog.fragment.xml
# rootWithPython310/root/ui5/browser/view/settingsmenu.fragment.xml
# rootWithPython310/root/ui5/browser/view/tabsmenu.fragment.xml
# rootWithPython310/root/ui5/browser/Component.js
# rootWithPython310/root/ui5/browser/model/
# rootWithPython310/root/ui5/browser/model/BrowserListBinding.js
# rootWithPython310/root/ui5/browser/model/BrowserModel.js
# rootWithPython310/root/ui5/tree/
# rootWithPython310/root/ui5/tree/controller/
# rootWithPython310/root/ui5/tree/controller/TreeViewer.controller.js
# rootWithPython310/root/ui5/tree/index.html
# rootWithPython310/root/ui5/tree/manifest.json
# rootWithPython310/root/ui5/tree/view/
# rootWithPython310/root/ui5/tree/view/TreeViewer.view.xml
# rootWithPython310/root/ui5/tree/view/BranchHelpDialog.fragment.xml
# rootWithPython310/root/ui5/tree/Component.js
# rootWithPython310/root/macros/
# rootWithPython310/root/macros/fileopen.C
# rootWithPython310/root/macros/Dialogs.C
# rootWithPython310/root/js/
# rootWithPython310/root/js/img/
# rootWithPython310/root/js/img/RootIcon.ico
# rootWithPython310/root/js/changes.md
# rootWithPython310/root/js/scripts/
# rootWithPython310/root/js/scripts/JSRoot.core.js
# rootWithPython310/root/js/scripts/geoworker.js
# rootWithPython310/root/js/modules/
# rootWithPython310/root/js/modules/base/
# rootWithPython310/root/js/modules/base/TAttMarkerHandler.mjs
# rootWithPython310/root/js/modules/base/ObjectPainter.mjs
# rootWithPython310/root/js/modules/base/FontHandler.mjs
# rootWithPython310/root/js/modules/base/TAttFillHandler.mjs
# rootWithPython310/root/js/modules/base/TAttLineHandler.mjs
# rootWithPython310/root/js/modules/base/BasePainter.mjs
# rootWithPython310/root/js/modules/base/colors.mjs
# rootWithPython310/root/js/modules/base/base3d.mjs
# rootWithPython310/root/js/modules/base/RObjectPainter.mjs
# rootWithPython310/root/js/modules/base/latex.mjs
# rootWithPython310/root/js/modules/base/TAttTextHandler.mjs
# rootWithPython310/root/js/modules/base/math.mjs
# rootWithPython310/root/js/modules/io.mjs
# rootWithPython310/root/js/modules/geom/
# rootWithPython310/root/js/modules/geom/bundle.mjs
# rootWithPython310/root/js/modules/geom/TGeoPainter.mjs
# rootWithPython310/root/js/modules/geom/geobase.mjs
# rootWithPython310/root/js/modules/geom/csg.mjs
# rootWithPython310/root/js/modules/gui/
# rootWithPython310/root/js/modules/gui/lil-gui.mjs
# rootWithPython310/root/js/modules/gui/HierarchyPainter.mjs
# rootWithPython310/root/js/modules/gui/menu.mjs
# rootWithPython310/root/js/modules/gui/display.mjs
# rootWithPython310/root/js/modules/gui/utils.mjs
# rootWithPython310/root/js/modules/three.mjs
# rootWithPython310/root/js/modules/hist/
# rootWithPython310/root/js/modules/hist/THStackPainter.mjs
# rootWithPython310/root/js/modules/hist/hist3d.mjs
# rootWithPython310/root/js/modules/hist/TH2Painter.mjs
# rootWithPython310/root/js/modules/hist/bundle.mjs
# rootWithPython310/root/js/modules/hist/TH1Painter.mjs
# rootWithPython310/root/js/modules/hist/TPavePainter.mjs
# rootWithPython310/root/js/modules/hist/RPavePainter.mjs
# rootWithPython310/root/js/modules/hist/TEfficiencyPainter.mjs
# rootWithPython310/root/js/modules/hist/RH3Painter.mjs
# rootWithPython310/root/js/modules/hist/TF2Painter.mjs
# rootWithPython310/root/js/modules/hist/RH2Painter.mjs
# rootWithPython310/root/js/modules/hist/RH1Painter.mjs
# rootWithPython310/root/js/modules/hist/TH3Painter.mjs
# rootWithPython310/root/js/modules/hist/TGraphTimePainter.mjs
# rootWithPython310/root/js/modules/hist/TGraph2DPainter.mjs
# rootWithPython310/root/js/modules/hist/TMultiGraphPainter.mjs
# rootWithPython310/root/js/modules/hist/TF1Painter.mjs
# rootWithPython310/root/js/modules/hist/TGraphPainter.mjs
# rootWithPython310/root/js/modules/tree.mjs
# rootWithPython310/root/js/modules/hist2d/
# rootWithPython310/root/js/modules/hist2d/THistPainter.mjs
# rootWithPython310/root/js/modules/hist2d/TH2Painter.mjs
# rootWithPython310/root/js/modules/hist2d/bundle.mjs
# rootWithPython310/root/js/modules/hist2d/TH1Painter.mjs
# rootWithPython310/root/js/modules/hist2d/RH2Painter.mjs
# rootWithPython310/root/js/modules/hist2d/RH1Painter.mjs
# rootWithPython310/root/js/modules/hist2d/TScatterPainter.mjs
# rootWithPython310/root/js/modules/hist2d/RHistPainter.mjs
# rootWithPython310/root/js/modules/hist2d/TMultiGraphPainter.mjs
# rootWithPython310/root/js/modules/hist2d/TGraphPainter.mjs
# rootWithPython310/root/js/modules/draw.mjs
# rootWithPython310/root/js/modules/main.mjs
# rootWithPython310/root/js/modules/gui.mjs
# rootWithPython310/root/js/modules/core.mjs
# rootWithPython310/root/js/modules/draw/
# rootWithPython310/root/js/modules/draw/TArrowPainter.mjs
# rootWithPython310/root/js/modules/draw/TRatioPlotPainter.mjs
# rootWithPython310/root/js/modules/draw/more.mjs
# rootWithPython310/root/js/modules/draw/TGaxisPainter.mjs
# rootWithPython310/root/js/modules/draw/TSplinePainter.mjs
# rootWithPython310/root/js/modules/draw/TGraphPolarPainter.mjs
# rootWithPython310/root/js/modules/draw/TWebPaintingPainter.mjs
# rootWithPython310/root/js/modules/draw/TPolyMarker3D.mjs
# rootWithPython310/root/js/modules/draw/draw3d.mjs
# rootWithPython310/root/js/modules/draw/v7more.mjs
# rootWithPython310/root/js/modules/draw/TTree.mjs
# rootWithPython310/root/js/modules/draw/TASImagePainter.mjs
# rootWithPython310/root/js/modules/draw/TLinePainter.mjs
# rootWithPython310/root/js/modules/gpad/
# rootWithPython310/root/js/modules/gpad/TAxisPainter.mjs
# rootWithPython310/root/js/modules/gpad/TCanvasPainter.mjs
# rootWithPython310/root/js/modules/gpad/RFramePainter.mjs
# rootWithPython310/root/js/modules/gpad/RPadPainter.mjs
# rootWithPython310/root/js/modules/gpad/TPadPainter.mjs
# rootWithPython310/root/js/modules/gpad/RAxisPainter.mjs
# rootWithPython310/root/js/modules/gpad/RCanvasPainter.mjs
# rootWithPython310/root/js/modules/gpad/TFramePainter.mjs
# rootWithPython310/root/js/modules/webwindow.mjs
# rootWithPython310/root/js/modules/d3.mjs
# rootWithPython310/root/js/files/
# rootWithPython310/root/js/files/draw.htm
# rootWithPython310/root/js/files/web.config
# rootWithPython310/root/js/files/wslist.htm
# rootWithPython310/root/js/files/online.htm
# rootWithPython310/root/js/files/geom_batch.htm
# rootWithPython310/root/js/files/canv_batch.htm
# rootWithPython310/root/js/build/
# rootWithPython310/root/js/build/jsroot.js
# rootWithPython310/root/js/index.htm
# rootWithPython310/root/js/LICENSE
# rootWithPython310/root/icons/
# rootWithPython310/root/icons/fileopen.xpm
# rootWithPython310/root/icons/sm_new.xpm
# rootWithPython310/root/icons/about.xpm
# rootWithPython310/root/icons/refresh2.xpm
# rootWithPython310/root/icons/htmlfile.gif
# rootWithPython310/root/icons/object_folder_s.xpm
# rootWithPython310/root/icons/bld_layout_d.xpm
# rootWithPython310/root/icons/bld_undo.xpm
# rootWithPython310/root/icons/Root6Splash.xpm
# rootWithPython310/root/icons/bld_grab_d.xpm
# rootWithPython310/root/icons/pavestext.xpm
# rootWithPython310/root/icons/bld_grab.xpm
# rootWithPython310/root/icons/mdi_help.xpm
# rootWithPython310/root/icons/filter.png
# rootWithPython310/root/icons/ed_delete.png
# rootWithPython310/root/icons/monitor01.xpm
# rootWithPython310/root/icons/unchecked_dis_t.xpm
# rootWithPython310/root/icons/disconnect.xpm
# rootWithPython310/root/icons/c_src_t.xpm
# rootWithPython310/root/icons/query_submit.xpm
# rootWithPython310/root/icons/marker23.xpm
# rootWithPython310/root/icons/geoctub_s.xpm
# rootWithPython310/root/icons/mdi_maximize.xpm
# rootWithPython310/root/icons/draw_t.xpm
# rootWithPython310/root/icons/sm_import_macro.xpm
# rootWithPython310/root/icons/chain_s.xpm
# rootWithPython310/root/icons/eve_viewer.xpm
# rootWithPython310/root/icons/first_t.xpm
# rootWithPython310/root/icons/cut_t.xpm
# rootWithPython310/root/icons/bld_AlignBtm.xpm
# rootWithPython310/root/icons/monitor02.xpm
# rootWithPython310/root/icons/geogtra_t.xpm
# rootWithPython310/root/icons/bld_AlignLeft.png
# rootWithPython310/root/icons/tmacro_s.xpm
# rootWithPython310/root/icons/ed_cut.png
# rootWithPython310/root/icons/ed_paste.png
# rootWithPython310/root/icons/local_session.xpm
# rootWithPython310/root/icons/bld_vbox.png
# rootWithPython310/root/icons/Root6Splash.png
# rootWithPython310/root/icons/closetab_d.png
# rootWithPython310/root/icons/ReloadPage.gif
# rootWithPython310/root/icons/georotation_t.xpm
# rootWithPython310/root/icons/bld_hprogressbar.xpm
# rootWithPython310/root/icons/rootdb_s.xpm
# rootWithPython310/root/icons/marker18.xpm
# rootWithPython310/root/icons/bld_colorselect.png
# rootWithPython310/root/icons/x_pic.xpm
# rootWithPython310/root/icons/geosphere_s.xpm
# rootWithPython310/root/icons/geocone_s.xpm
# rootWithPython310/root/icons/query_disconnected.xpm
# rootWithPython310/root/icons/georotation_s.xpm
# rootWithPython310/root/icons/branch-cl_t.xpm
# rootWithPython310/root/icons/geoarb8_s.xpm
# rootWithPython310/root/icons/marker.xpm
# rootWithPython310/root/icons/mdi_minimize.xpm
# rootWithPython310/root/icons/bld_AlignTop.png
# rootWithPython310/root/icons/marker1.xpm
# rootWithPython310/root/icons/Root6SplashEXT.xpm
# rootWithPython310/root/icons/bld_open.png
# rootWithPython310/root/icons/mb_stop_s.xpm
# rootWithPython310/root/icons/rbutton_off.xpm
# rootWithPython310/root/icons/sm_help.xpm
# rootWithPython310/root/icons/geopgon_t.xpm
# rootWithPython310/root/icons/geobbox_t.xpm
# rootWithPython310/root/icons/deb_s.xpm
# rootWithPython310/root/icons/profile_s.xpm
# rootWithPython310/root/icons/arc.xpm
# rootWithPython310/root/icons/listview.xpm
# rootWithPython310/root/icons/tb_bigicons.xpm
# rootWithPython310/root/icons/bld_canvas.1.xpm
# rootWithPython310/root/icons/bld_break_d.xpm
# rootWithPython310/root/icons/geotrd1_t.xpm
# rootWithPython310/root/icons/ed_interrupt.png
# rootWithPython310/root/icons/bld_listbox.xpm
# rootWithPython310/root/icons/geocombi_t.xpm
# rootWithPython310/root/icons/branch_folder_s.xpm
# rootWithPython310/root/icons/package_add.xpm
# rootWithPython310/root/icons/bld_AlignTop_d.xpm
# rootWithPython310/root/icons/glow_red.png
# rootWithPython310/root/icons/bld_crop_d.xpm
# rootWithPython310/root/icons/geocomposite_s.xpm
# rootWithPython310/root/icons/leaf_method_s.xpm
# rootWithPython310/root/icons/cut-disable_t.xpm
# rootWithPython310/root/icons/member.png
# rootWithPython310/root/icons/speedo.gif
# rootWithPython310/root/icons/bld_paste.xpm
# rootWithPython310/root/icons/bld_cut.png
# rootWithPython310/root/icons/bld_groupframe.xpm
# rootWithPython310/root/icons/arrow_left.xpm
# rootWithPython310/root/icons/bld_stop.png
# rootWithPython310/root/icons/bld_copy.xpm
# rootWithPython310/root/icons/fdisk_t.xpm
# rootWithPython310/root/icons/tb_find.xpm
# rootWithPython310/root/icons/replay.png
# rootWithPython310/root/icons/bld_grid.xpm
# rootWithPython310/root/icons/curlyline.xpm
# rootWithPython310/root/icons/bld_removetab.png
# rootWithPython310/root/icons/latex.xpm
# rootWithPython310/root/icons/geotubeseg_t.xpm
# rootWithPython310/root/icons/geotorus_s.xpm
# rootWithPython310/root/icons/ed_saveas.png
# rootWithPython310/root/icons/geotrd1_s.xpm
# rootWithPython310/root/icons/unchecked_t.xpm
# rootWithPython310/root/icons/eve_scene.xpm
# rootWithPython310/root/icons/bld_vscrollbar.xpm
# rootWithPython310/root/icons/bld_vbox_d.xpm
# rootWithPython310/root/icons/glow_orange.png
# rootWithPython310/root/icons/proof_disconnected.xpm
# rootWithPython310/root/icons/sliderh.xpm
# rootWithPython310/root/icons/rootdb_t.xpm
# rootWithPython310/root/icons/bld_crop.png
# rootWithPython310/root/icons/GoForward.gif
# rootWithPython310/root/icons/bld_cut.xpm
# rootWithPython310/root/icons/geoeltu_t.xpm
# rootWithPython310/root/icons/tb_smicons.xpm
# rootWithPython310/root/icons/bld_delete.png
# rootWithPython310/root/icons/properties.xpm
# rootWithPython310/root/icons/rotate.png
# rootWithPython310/root/icons/glow_green.png
# rootWithPython310/root/icons/tb_list.xpm
# rootWithPython310/root/icons/bld_open.xpm
# rootWithPython310/root/icons/rpm_t.xpm
# rootWithPython310/root/icons/rootdblnk_s.xpm
# rootWithPython310/root/icons/bld_AlignTop.xpm
# rootWithPython310/root/icons/return_object_t.xpm
# rootWithPython310/root/icons/bld_replace_d.xpm
# rootWithPython310/root/icons/pause.png
# rootWithPython310/root/icons/pack_t.xpm
# rootWithPython310/root/icons/ntuple_s.xpm
# rootWithPython310/root/icons/folder_s.xpm
# rootWithPython310/root/icons/checked_t.xpm
# rootWithPython310/root/icons/geoctub_t.xpm
# rootWithPython310/root/icons/marker5.xpm
# rootWithPython310/root/icons/selection_t.xpm
# rootWithPython310/root/icons/geocone_t.xpm
# rootWithPython310/root/icons/h_src_s.xpm
# rootWithPython310/root/icons/geomedium_s.xpm
# rootWithPython310/root/icons/marker22.xpm
# rootWithPython310/root/icons/geotranslation_s.xpm
# rootWithPython310/root/icons/marker24.xpm
# rootWithPython310/root/icons/bld_tab.xpm
# rootWithPython310/root/icons/tree_t.xpm
# rootWithPython310/root/icons/monitor03.xpm
# rootWithPython310/root/icons/bld_rgb.png
# rootWithPython310/root/icons/ed_help.png
# rootWithPython310/root/icons/bld_bg.png
# rootWithPython310/root/icons/bld_listtree.xpm
# rootWithPython310/root/icons/bld_sortup.png
# rootWithPython310/root/icons/rpm_s.xpm
# rootWithPython310/root/icons/ed_print.png
# rootWithPython310/root/icons/h1_s.xpm
# rootWithPython310/root/icons/geomedium_t.xpm
# rootWithPython310/root/icons/bld_AlignRight_d.xpm
# rootWithPython310/root/icons/closetab.png
# rootWithPython310/root/icons/bld_vseparator.xpm
# rootWithPython310/root/icons/deb_t.xpm
# rootWithPython310/root/icons/geotrap_t.xpm
# rootWithPython310/root/icons/tb_details.xpm
# rootWithPython310/root/icons/sm_export.xpm
# rootWithPython310/root/icons/eve_line.xpm
# rootWithPython310/root/icons/bld_bg.xpm
# rootWithPython310/root/icons/macro_s.xpm
# rootWithPython310/root/icons/bld_copy_d.xpm
# rootWithPython310/root/icons/geopgon_s.xpm
# rootWithPython310/root/icons/query_connected.xpm
# rootWithPython310/root/icons/leaf_method_t.xpm
# rootWithPython310/root/icons/browser.xpm
# rootWithPython310/root/icons/h2_s.xpm
# rootWithPython310/root/icons/checked_dis_t.xpm
# rootWithPython310/root/icons/record.png
# rootWithPython310/root/icons/geoparab_s.xpm
# rootWithPython310/root/icons/h1_t.xpm
# rootWithPython310/root/icons/bld_copy.png
# rootWithPython310/root/icons/pavetext.xpm
# rootWithPython310/root/icons/geotrap_s.xpm
# rootWithPython310/root/icons/checkmark_t.xpm
# rootWithPython310/root/icons/pad.xpm
# rootWithPython310/root/icons/previous_t.xpm
# rootWithPython310/root/icons/geoconeseg_s.xpm
# rootWithPython310/root/icons/record_t.xpm
# rootWithPython310/root/icons/connect.xpm
# rootWithPython310/root/icons/bld_hpaned.xpm
# rootWithPython310/root/icons/geotranslation_t.xpm
# rootWithPython310/root/icons/bld_vbox.xpm
# rootWithPython310/root/icons/h_src_t.xpm
# rootWithPython310/root/icons/bld_new.xpm
# rootWithPython310/root/icons/bld_grid_d.xpm
# rootWithPython310/root/icons/ver_arrow_cursor.png
# rootWithPython310/root/icons/ed_goto.png
# rootWithPython310/root/icons/bld_break.xpm
# rootWithPython310/root/icons/bld_plus.png
# rootWithPython310/root/icons/bld_delete.xpm
# rootWithPython310/root/icons/home_t.xpm
# rootWithPython310/root/icons/geovolume_s.xpm
# rootWithPython310/root/icons/mdi_restore.xpm
# rootWithPython310/root/icons/marker6.xpm
# rootWithPython310/root/icons/refresh.png
# rootWithPython310/root/icons/h3_s.xpm
# rootWithPython310/root/icons/eve_text.gif
# rootWithPython310/root/icons/bld_AlignRight.png
# rootWithPython310/root/icons/arrow_right.xpm
# rootWithPython310/root/icons/bld_edit.xpm
# rootWithPython310/root/icons/geomaterial_s.xpm
# rootWithPython310/root/icons/Root6Icon.png
# rootWithPython310/root/icons/bld_AlignLeft.xpm
# rootWithPython310/root/icons/bld_pointer.xpm
# rootWithPython310/root/icons/quit.xpm
# rootWithPython310/root/icons/bld_paste_into.png
# rootWithPython310/root/icons/sm_delete.xpm
# rootWithPython310/root/icons/method.png
# rootWithPython310/root/icons/rootdblnk_t.xpm
# rootWithPython310/root/icons/bld_combobox.xpm
# rootWithPython310/root/icons/geotorus_t.xpm
# rootWithPython310/root/icons/bld_label.xpm
# rootWithPython310/root/icons/RootIcon.ico
# rootWithPython310/root/icons/marker30.xpm
# rootWithPython310/root/icons/stop.png
# rootWithPython310/root/icons/mdi_default.xpm
# rootWithPython310/root/icons/arrow_down.xpm
# rootWithPython310/root/icons/bld_radiobutton.xpm
# rootWithPython310/root/icons/geomixture_s.xpm
# rootWithPython310/root/icons/geobbox_s.xpm
# rootWithPython310/root/icons/tb_back.xpm
# rootWithPython310/root/icons/tmacro_t.xpm
# rootWithPython310/root/icons/tb_forw.xpm
# rootWithPython310/root/icons/bld_newtab.png
# rootWithPython310/root/icons/geohype_t.xpm
# rootWithPython310/root/icons/marker4.xpm
# rootWithPython310/root/icons/bld_AlignBtm_d.xpm
# rootWithPython310/root/icons/proof_base.xpm
# rootWithPython310/root/icons/rbutton_on.xpm
# rootWithPython310/root/icons/netdisk_s.xpm
# rootWithPython310/root/icons/bld_save.png
# rootWithPython310/root/icons/next_t.xpm
# rootWithPython310/root/icons/bld_redo.xpm
# rootWithPython310/root/icons/pdf.xpm
# rootWithPython310/root/icons/tree_s.xpm
# rootWithPython310/root/icons/mdi_close.xpm
# rootWithPython310/root/icons/mb_exclamation_s.xpm
# rootWithPython310/root/icons/slink_t.xpm
# rootWithPython310/root/icons/sm_import_canvas.xpm
# rootWithPython310/root/icons/geosphere_t.xpm
# rootWithPython310/root/icons/y_pic.xpm
# rootWithPython310/root/icons/ed_save.png
# rootWithPython310/root/icons/bld_undo.png
# rootWithPython310/root/icons/printer_s.xpm
# rootWithPython310/root/icons/h2_t.xpm
# rootWithPython310/root/icons/geopcon_s.xpm
# rootWithPython310/root/icons/geomixture_t.xpm
# rootWithPython310/root/icons/bld_vpaned.xpm
# rootWithPython310/root/icons/bld_text.xpm
# rootWithPython310/root/icons/chain_t.xpm
# rootWithPython310/root/icons/mb_question_s.xpm
# rootWithPython310/root/icons/marker27.xpm
# rootWithPython310/root/icons/bld_entry.xpm
# rootWithPython310/root/icons/eve_track.xpm
# rootWithPython310/root/icons/geoassembly_s.xpm
# rootWithPython310/root/icons/bld_checkbutton.xpm
# rootWithPython310/root/icons/geoarb8_t.xpm
# rootWithPython310/root/icons/ed_quit.png
# rootWithPython310/root/icons/folder_t.xpm
# rootWithPython310/root/icons/open.xpm
# rootWithPython310/root/icons/button.xpm
# rootWithPython310/root/icons/refresh1.xpm
# rootWithPython310/root/icons/splitterh.xpm
# rootWithPython310/root/icons/bld_redo.png
# rootWithPython310/root/icons/arrow.xpm
# rootWithPython310/root/icons/geohype_s.xpm
# rootWithPython310/root/icons/eve_axes.xpm
# rootWithPython310/root/icons/bld_rename.png
# rootWithPython310/root/icons/bld_embedcanvas.xpm
# rootWithPython310/root/icons/bld_exit.png
# rootWithPython310/root/icons/eve_rnr11_t.xpm
# rootWithPython310/root/icons/hpp_src_t.xpm
# rootWithPython310/root/icons/bld_mainframe.xpm
# rootWithPython310/root/icons/ed_execute.png
# rootWithPython310/root/icons/top_right_cursor.png
# rootWithPython310/root/icons/netdisk_t.xpm
# rootWithPython310/root/icons/bld_paste.png
# rootWithPython310/root/icons/slider1h.xpm
# rootWithPython310/root/icons/bld_statusbar.xpm
# rootWithPython310/root/icons/bld_image.xpm
# rootWithPython310/root/icons/bld_numberentry.xpm
# rootWithPython310/root/icons/ed_findnext.png
# rootWithPython310/root/icons/mb_asterisk_s.xpm
# rootWithPython310/root/icons/ellipse.xpm
# rootWithPython310/root/icons/root_s.xpm
# rootWithPython310/root/icons/bld_fontselect.png
# rootWithPython310/root/icons/marker29.xpm
# rootWithPython310/root/icons/psp_s.xpm
# rootWithPython310/root/icons/GoHome.gif
# rootWithPython310/root/icons/bld_hslider.xpm
# rootWithPython310/root/icons/slink_s.xpm
# rootWithPython310/root/icons/ed_find.png
# rootWithPython310/root/icons/splitterv.xpm
# rootWithPython310/root/icons/newcanvas.xpm
# rootWithPython310/root/icons/slider2v.xpm
# rootWithPython310/root/icons/bld_edit.png
# rootWithPython310/root/icons/arrow_right2.xpm
# rootWithPython310/root/icons/curlyarc.xpm
# rootWithPython310/root/icons/diamond.xpm
# rootWithPython310/root/icons/geocomposite_t.xpm
# rootWithPython310/root/icons/return_object_s.xpm
# rootWithPython310/root/icons/h3_t.xpm
# rootWithPython310/root/icons/bld_vprogressbar.xpm
# rootWithPython310/root/icons/f1_t.xpm
# rootWithPython310/root/icons/bld_AlignBtm.png
# rootWithPython310/root/icons/branch-ob_t.xpm
# rootWithPython310/root/icons/hor_arrow_cursor.png
# rootWithPython310/root/icons/eve_rnr10_t.xpm
# rootWithPython310/root/icons/bld_save_d.xpm
# rootWithPython310/root/icons/geotubeseg_s.xpm
# rootWithPython310/root/icons/bld_AlignRight.xpm
# rootWithPython310/root/icons/inspect.xpm
# rootWithPython310/root/icons/app_t.xpm
# rootWithPython310/root/icons/geoeltu_s.xpm
# rootWithPython310/root/icons/cdrom_t.xpm
# rootWithPython310/root/icons/bld_rgb.xpm
# rootWithPython310/root/icons/marker3.xpm
# rootWithPython310/root/icons/interrupt.xpm
# rootWithPython310/root/icons/marker25.xpm
# rootWithPython310/root/icons/class.png
# rootWithPython310/root/icons/stop_t.xpm
# rootWithPython310/root/icons/branch_t.xpm
# rootWithPython310/root/icons/cpp_src_s.xpm
# rootWithPython310/root/icons/marker28.xpm
# rootWithPython310/root/icons/bld_shutter.png
# rootWithPython310/root/icons/proof_connected.xpm
# rootWithPython310/root/icons/ed_open.png
# rootWithPython310/root/icons/right_arrow_cursor.png
# rootWithPython310/root/icons/eve_pointset.xpm
# rootWithPython310/root/icons/ed_compile.png
# rootWithPython310/root/icons/info.gif
# rootWithPython310/root/icons/Splash.gif
# rootWithPython310/root/icons/ps_t.xpm
# rootWithPython310/root/icons/hpp_src_s.xpm
# rootWithPython310/root/icons/object_folder_t.xpm
# rootWithPython310/root/icons/pack-empty_t.xpm
# rootWithPython310/root/icons/bld_replace.xpm
# rootWithPython310/root/icons/eve_rnr00_t.xpm
# rootWithPython310/root/icons/bld_AlignCenter.png
# rootWithPython310/root/icons/save.xpm
# rootWithPython310/root/icons/bld_compact.png
# rootWithPython310/root/icons/geotube_s.xpm
# rootWithPython310/root/icons/bld_canvas.xpm
# rootWithPython310/root/icons/slider2h.xpm
# rootWithPython310/root/icons/printer.xpm
# rootWithPython310/root/icons/geoconeseg_t.xpm
# rootWithPython310/root/icons/bld_break.png
# rootWithPython310/root/icons/geoassembly_t.xpm
# rootWithPython310/root/icons/ed_new.png
# rootWithPython310/root/icons/f1_s.xpm
# rootWithPython310/root/icons/query_new.xpm
# rootWithPython310/root/icons/graph.xpm
# rootWithPython310/root/icons/expression_t.xpm
# rootWithPython310/root/icons/geoxtru_s.xpm
# rootWithPython310/root/icons/bld_edit_s.png
# rootWithPython310/root/icons/geoxtru_t.xpm
# rootWithPython310/root/icons/app_s.xpm
# rootWithPython310/root/icons/bld_grid.png
# rootWithPython310/root/icons/geoparab_t.xpm
# rootWithPython310/root/icons/pave.xpm
# rootWithPython310/root/icons/psp_t.xpm
# rootWithPython310/root/icons/marker26.xpm
# rootWithPython310/root/icons/geomaterial_t.xpm
# rootWithPython310/root/icons/recursor.png
# rootWithPython310/root/icons/monitor04.xpm
# rootWithPython310/root/icons/modify.xpm
# rootWithPython310/root/icons/pointer.xpm
# rootWithPython310/root/icons/slider1v.xpm
# rootWithPython310/root/icons/bld_layout.xpm
# rootWithPython310/root/icons/doc_t.xpm
# rootWithPython310/root/icons/last_t.xpm
# rootWithPython310/root/icons/line.xpm
# rootWithPython310/root/icons/bld_new.png
# rootWithPython310/root/icons/geopara_t.xpm
# rootWithPython310/root/icons/eve_rnr01_t.xpm
# rootWithPython310/root/icons/bld_cut_d.xpm
# rootWithPython310/root/icons/hdisk_t.xpm
# rootWithPython310/root/icons/pavelabel.xpm
# rootWithPython310/root/icons/bld_redo_d.xpm
# rootWithPython310/root/icons/bld_stop.xpm
# rootWithPython310/root/icons/geocombi_s.xpm
# rootWithPython310/root/icons/geotrd2_s.xpm
# rootWithPython310/root/icons/tb_uplevel.xpm
# rootWithPython310/root/icons/rbutton_dis_off.xpm
# rootWithPython310/root/icons/Splash.xpm
# rootWithPython310/root/icons/bld_hseparator.xpm
# rootWithPython310/root/icons/f2_s.xpm
# rootWithPython310/root/icons/bld_textbutton.xpm
# rootWithPython310/root/icons/ed_copy.png
# rootWithPython310/root/icons/bld_paste_d.xpm
# rootWithPython310/root/icons/GoBack.gif
# rootWithPython310/root/icons/profile_t.xpm
# rootWithPython310/root/icons/sliderv.xpm
# rootWithPython310/root/icons/bld_hscrollbar.xpm
# rootWithPython310/root/icons/leaf_s.xpm
# rootWithPython310/root/icons/bld_hbox.xpm
# rootWithPython310/root/icons/cpp_src_t.xpm
# rootWithPython310/root/icons/c_src_s.xpm
# rootWithPython310/root/icons/bld_hbox.png
# rootWithPython310/root/icons/tb_newfolder.xpm
# rootWithPython310/root/icons/bld_crop.xpm
# rootWithPython310/root/icons/StopLoading.gif
# rootWithPython310/root/icons/bld_hbox_d.xpm
# rootWithPython310/root/icons/marker8.xpm
# rootWithPython310/root/icons/bld_AlignLeft_d.xpm
# rootWithPython310/root/icons/refresh.xpm
# rootWithPython310/root/icons/macro_t.xpm
# rootWithPython310/root/icons/ntuple_t.xpm
# rootWithPython310/root/icons/package_delete.xpm
# rootWithPython310/root/icons/marker2.xpm
# rootWithPython310/root/icons/geotube_t.xpm
# rootWithPython310/root/icons/geopcon_t.xpm
# rootWithPython310/root/icons/geotrd2_t.xpm
# rootWithPython310/root/icons/doc_s.xpm
# rootWithPython310/root/icons/bld_fontselect.gif
# rootWithPython310/root/icons/root_t.xpm
# rootWithPython310/root/icons/cut.xpm
# rootWithPython310/root/icons/leaf_t.xpm
# rootWithPython310/root/icons/z_pic.xpm
# rootWithPython310/root/icons/tb_refresh.xpm
# rootWithPython310/root/icons/bld_delete_d.xpm
# rootWithPython310/root/icons/marker16.xpm
# rootWithPython310/root/icons/marker21.xpm
# rootWithPython310/root/icons/bld_vslider.xpm
# rootWithPython310/root/icons/rbutton_dis_on.xpm
# rootWithPython310/root/icons/move_cursor.png
# rootWithPython310/root/icons/marker20.xpm
# rootWithPython310/root/icons/top_left_cursor.png
# rootWithPython310/root/icons/bld_bgd.xpm
# rootWithPython310/root/icons/ps_s.xpm
# rootWithPython310/root/icons/bld_colorselect.xpm
# rootWithPython310/root/icons/geovolume_t.xpm
# rootWithPython310/root/icons/bld_undo_d.xpm
# rootWithPython310/root/icons/ofolder_t.xpm
# rootWithPython310/root/icons/marker7.xpm
# rootWithPython310/root/icons/filesaveas.xpm
# rootWithPython310/root/icons/geogtra_s.xpm
# rootWithPython310/root/icons/branch_folder_t.xpm
# rootWithPython310/root/icons/bld_save.xpm
# rootWithPython310/root/icons/geopara_s.xpm
# rootWithPython310/root/icons/f2_t.xpm
# rootWithPython310/root/icons/arrow_up.xpm
# rootWithPython310/root/icons/package.xpm
# rootWithPython310/root/cmake/
# rootWithPython310/root/cmake/RootMacros.cmake
# rootWithPython310/root/cmake/ROOTConfig-targets.cmake
# rootWithPython310/root/cmake/ROOTUseFile.cmake
# rootWithPython310/root/cmake/ROOTConfig-version.cmake
# rootWithPython310/root/cmake/ROOTConfig.cmake
# rootWithPython310/root/cmake/ROOTConfig-targets-release.cmake
# rootWithPython310/root/cmake/RootTestDriver.cmake
# rootWithPython310/root/fonts/
# rootWithPython310/root/fonts/STIXGeneral.otf
# rootWithPython310/root/fonts/courbd.ttf
# rootWithPython310/root/fonts/FreeMonoBold.otf
# rootWithPython310/root/fonts/comic.ttf
# rootWithPython310/root/fonts/FreeSerifBold.otf
# rootWithPython310/root/fonts/verdanai.ttf
# rootWithPython310/root/fonts/georgiab.ttf
# rootWithPython310/root/fonts/arialbi.ttf
# rootWithPython310/root/fonts/timesi.ttf
# rootWithPython310/root/fonts/DroidSansFallback.ttf
# rootWithPython310/root/fonts/arial.ttf
# rootWithPython310/root/fonts/monotype.ttf
# rootWithPython310/root/fonts/STIXSiz2SymBol.otf
# rootWithPython310/root/fonts/FreeSansBold.otf
# rootWithPython310/root/fonts/FreeMonoOblique.otf
# rootWithPython310/root/fonts/FreeMono.otf
# rootWithPython310/root/fonts/webdings.ttf
# rootWithPython310/root/fonts/STIXSiz1SymBol.otf
# rootWithPython310/root/fonts/STIXSiz2Sym.otf
# rootWithPython310/root/fonts/georgiai.ttf
# rootWithPython310/root/fonts/FreeSansBoldOblique.otf
# rootWithPython310/root/fonts/trebucbd.ttf
# rootWithPython310/root/fonts/FreeSansOblique.otf
# rootWithPython310/root/fonts/timesbd.ttf
# rootWithPython310/root/fonts/georgia.ttf
# rootWithPython310/root/fonts/trebuc.ttf
# rootWithPython310/root/fonts/FreeSerif.otf
# rootWithPython310/root/fonts/verdanab.ttf
# rootWithPython310/root/fonts/STIXSiz3Sym.otf
# rootWithPython310/root/fonts/ariblk.ttf
# rootWithPython310/root/fonts/STIXSiz4SymBol.otf
# rootWithPython310/root/fonts/georgiaz.ttf
# rootWithPython310/root/fonts/STIXSiz3SymBol.otf
# rootWithPython310/root/fonts/trebucbi.ttf
# rootWithPython310/root/fonts/impact.ttf
# rootWithPython310/root/fonts/BlackChancery.ttf
# rootWithPython310/root/fonts/FreeSerifItalic.otf
# rootWithPython310/root/fonts/times.ttf
# rootWithPython310/root/fonts/trebucit.ttf
# rootWithPython310/root/fonts/FreeMonoBoldOblique.otf
# rootWithPython310/root/fonts/courbi.ttf
# rootWithPython310/root/fonts/STIXGeneralBol.otf
# rootWithPython310/root/fonts/LICENSE
# rootWithPython310/root/fonts/STIXSiz1Sym.otf
# rootWithPython310/root/fonts/STIXGeneralBolIta.otf
# rootWithPython310/root/fonts/STIXGeneralItalic.otf
# rootWithPython310/root/fonts/couri.ttf
# rootWithPython310/root/fonts/STIXSiz4Sym.otf
# rootWithPython310/root/fonts/symbol.ttf
# rootWithPython310/root/fonts/ariali.ttf
# rootWithPython310/root/fonts/FreeSerifBoldItalic.otf
# rootWithPython310/root/fonts/timesbi.ttf
# rootWithPython310/root/fonts/verdana.ttf
# rootWithPython310/root/fonts/FreeSans.otf
# rootWithPython310/root/fonts/comicbd.ttf
# rootWithPython310/root/fonts/verdanaz.ttf
# rootWithPython310/root/fonts/wingding.ttf
# rootWithPython310/root/fonts/arialbd.ttf
# rootWithPython310/root/fonts/STIXSiz5Sym.otf
# rootWithPython310/root/fonts/cour.ttf
# rootWithPython310/include/
# rootWithPython310/include/TNotifyLink.h
# rootWithPython310/include/TDSet.h
# rootWithPython310/include/TGeoArb8.h
# rootWithPython310/include/TF12.h
# rootWithPython310/include/TSPHE.h
# rootWithPython310/include/TXMLNode.h
# rootWithPython310/include/TGeoCache.h
# rootWithPython310/include/TArrayL64.h
# rootWithPython310/include/RooStringView.h
# rootWithPython310/include/TRootSecContext.h
# rootWithPython310/include/RGitCommit.h
# rootWithPython310/include/TTRD1.h
# rootWithPython310/include/TGeoPcon.h
# rootWithPython310/include/TBuffer3D.h
# rootWithPython310/include/RooFit/
# rootWithPython310/include/RooFit/Floats.h
# rootWithPython310/include/RooFit/Config.h
# rootWithPython310/include/RooFit/xRooFit/
# rootWithPython310/include/RooFit/xRooFit/xRooBrowser.h
# rootWithPython310/include/RooFit/xRooFit/xRooFit.h
# rootWithPython310/include/RooFit/xRooFit/xRooNode.h
# rootWithPython310/include/RooFit/xRooFit/Config.h
# rootWithPython310/include/RooFit/xRooFit/xRooHypoSpace.h
# rootWithPython310/include/RooFit/xRooFit/xRooNLLVar.h
# rootWithPython310/include/RooFit/UniqueId.h
# rootWithPython310/include/RooFit/ModelConfig.h
# rootWithPython310/include/RooFit/Detail/
# rootWithPython310/include/RooFit/Detail/DataMap.h
# rootWithPython310/include/RooFit/Detail/JSONInterface.h
# rootWithPython310/include/RooFit/Detail/CodeSquashContext.h
# rootWithPython310/include/RooFit/Detail/AnalyticalIntegrals.h
# rootWithPython310/include/RooFit/Detail/NormalizationHelpers.h
# rootWithPython310/include/RooFit/Detail/EvaluateFuncs.h
# rootWithPython310/include/RooFit/TestStatistics/
# rootWithPython310/include/RooFit/TestStatistics/RooAbsL.h
# rootWithPython310/include/RooFit/TestStatistics/LikelihoodWrapper.h
# rootWithPython310/include/RooFit/TestStatistics/buildLikelihood.h
# rootWithPython310/include/RooFit/TestStatistics/RooSubsidiaryL.h
# rootWithPython310/include/RooFit/TestStatistics/RooRealL.h
# rootWithPython310/include/RooFit/TestStatistics/RooSumL.h
# rootWithPython310/include/RooFit/TestStatistics/RooUnbinnedL.h
# rootWithPython310/include/RooFit/TestStatistics/LikelihoodGradientWrapper.h
# rootWithPython310/include/RooFit/TestStatistics/RooBinnedL.h
# rootWithPython310/include/TSpectrum2Fit.h
# rootWithPython310/include/TVirtualPaveStats.h
# rootWithPython310/include/TTF.h
# rootWithPython310/include/TAttText.h
# rootWithPython310/include/TAttBBox.h
# rootWithPython310/include/RooXYChi2Var.h
# rootWithPython310/include/TRootAuth.h
# rootWithPython310/include/TMatrixTBase.h
# rootWithPython310/include/TGrid.h
# rootWithPython310/include/TPosixThreadFactory.h
# rootWithPython310/include/TPieSliceEditor.h
# rootWithPython310/include/Riostream.h
# rootWithPython310/include/TGColorSelect.h
# rootWithPython310/include/TGraphTime.h
# rootWithPython310/include/TBranchProxy.h
# rootWithPython310/include/RooSimultaneous.h
# rootWithPython310/include/TGeoRegion.h
# ...
# rootWithPython310/doc/root/tutorials/dataframe/df027_SQliteDependencyOverVersion.C
# rootWithPython310/doc/root/tutorials/dataframe/df102_NanoAODDimuonAnalysis.C
# rootWithPython310/doc/root/tutorials/dataframe/df104_HiggsToTwoPhotons.py
# rootWithPython310/doc/root/tutorials/dataframe/df103_NanoAODHiggsAnalysis.C
# rootWithPython310/doc/root/tutorials/dataframe/df106_HiggsToFourLeptons.py
# rootWithPython310/doc/root/tutorials/dataframe/distrdf002_dask_connection.py
# rootWithPython310/doc/root/tutorials/dataframe/df107_SingleTopAnalysis.json
# rootWithPython310/doc/root/tutorials/dataframe/index.md
# rootWithPython310/doc/root/tutorials/dataframe/df019_Cache.py
# rootWithPython310/doc/root/tutorials/dataframe/df033_Describe.py
# rootWithPython310/doc/root/tutorials/dataframe/df001_introduction.py
# rootWithPython310/doc/root/tutorials/dataframe/df025_RNode.C
# rootWithPython310/doc/root/tutorials/dataframe/df017_vecOpsHEP.py
# rootWithPython310/doc/root/tutorials/dataframe/df105_WBosonAnalysis.py
# rootWithPython310/doc/root/tutorials/dataframe/df007_snapshot.C
# rootWithPython310/doc/root/tutorials/dataframe/df024_Display.py
# rootWithPython310/doc/root/tutorials/dataframe/df003_profiles.C
# rootWithPython310/doc/root/tutorials/dataframe/df034_SaveGraph.C
# rootWithPython310/doc/root/tutorials/dataframe/df021_createTGraph.py
# rootWithPython310/doc/root/tutorials/dataframe/df013_InspectAnalysis.C
# rootWithPython310/doc/root/tutorials/dataframe/df002_dataModel.C
# rootWithPython310/doc/root/tutorials/dataframe/df102_NanoAODDimuonAnalysis.py
# rootWithPython310/doc/root/tutorials/dataframe/df008_createDataSetFromScratch.C
# rootWithPython310/doc/root/tutorials/dataframe/df010_trivialDataSource.C
# rootWithPython310/doc/root/tutorials/dataframe/df014_CSVDataSource.C
# rootWithPython310/doc/root/tutorials/dataframe/df010_trivialDataSource.py
# rootWithPython310/doc/root/tutorials/dataframe/df103_NanoAODHiggsAnalysis.py
# rootWithPython310/doc/root/tutorials/dataframe/df006_ranges.py
# rootWithPython310/doc/root/tutorials/dataframe/df006_ranges.C
# rootWithPython310/doc/root/tutorials/dataframe/df004_cutFlowReport.py
# rootWithPython310/doc/root/tutorials/dataframe/df015_LazyDataSource.C
# rootWithPython310/doc/root/tutorials/dataframe/df028_SQliteIPLocation.C
# rootWithPython310/doc/root/tutorials/dataframe/df003_profiles.py
# rootWithPython310/doc/root/tutorials/dataframe/df106_HiggsToFourLeptons_spec.json
# rootWithPython310/doc/root/tutorials/dataframe/df034_SaveGraph.py
# rootWithPython310/doc/root/tutorials/dataframe/df019_Cache.C
# rootWithPython310/doc/root/tutorials/dataframe/df016_vecOps.py
# rootWithPython310/doc/root/tutorials/dataframe/df022_useKahan.C
# rootWithPython310/doc/root/tutorials/dataframe/df008_createDataSetFromScratch.py
# rootWithPython310/doc/root/tutorials/dataframe/df031_Stats.py
# rootWithPython310/doc/root/tutorials/dataframe/df021_createTGraph.C
# rootWithPython310/doc/root/tutorials/dataframe/df026_AsNumpyArrays.py
# rootWithPython310/doc/root/tutorials/dataframe/df018_customActions.C
# rootWithPython310/doc/root/tutorials/dataframe/df105_WBosonAnalysis.json
# rootWithPython310/doc/root/tutorials/dataframe/df020_helpers.C
# rootWithPython310/doc/root/tutorials/dataframe/df030_SQliteVersionsOfROOT.C
# rootWithPython310/doc/root/tutorials/dataframe/df014_CSVDataSource.py
# rootWithPython310/doc/root/tutorials/dataframe/df023_aggregate.C
# rootWithPython310/doc/root/tutorials/dataframe/df005_fillAnyObject.C
# rootWithPython310/doc/root/tutorials/dataframe/df001_introduction.C
# rootWithPython310/doc/root/tutorials/dataframe/distrdf001_spark_connection.py
# rootWithPython310/doc/root/tutorials/dataframe/df101_h1Analysis.C
# rootWithPython310/doc/root/tutorials/dataframe/df002_dataModel.py
# rootWithPython310/doc/root/tutorials/dataframe/df016_vecOps.C
# rootWithPython310/doc/root/tutorials/dataframe/df024_Display.C
# rootWithPython310/doc/root/tutorials/dataframe/df017_vecOpsHEP.root
# rootWithPython310/doc/root/tutorials/dataframe/df103_NanoAODHiggsAnalysis_python.h
# rootWithPython310/doc/root/tutorials/dataframe/df004_cutFlowReport.C
# rootWithPython310/doc/root/tutorials/dataframe/df107_SingleTopAnalysis.py
# rootWithPython310/doc/root/tutorials/dataframe/df032_RDFFromNumpy.py
# rootWithPython310/doc/root/tutorials/dataframe/df007_snapshot.py
# rootWithPython310/doc/root/tutorials/sql/
# rootWithPython310/doc/root/tutorials/sql/sqlselect.py
# rootWithPython310/doc/root/tutorials/sql/sqlselect.C
# rootWithPython310/doc/root/tutorials/sql/sqlfilldb.C
# rootWithPython310/doc/root/tutorials/sql/sqlcreatedb.C
# rootWithPython310/doc/root/tutorials/sql/sqlcanvas.C
# rootWithPython310/doc/root/tutorials/sql/SQLiteIPLocation.C
# rootWithPython310/doc/root/tutorials/sql/SQLiteTimeVersionOfRoot.C
# rootWithPython310/doc/root/tutorials/sql/sqlfilldb.py
# rootWithPython310/doc/root/tutorials/sql/sqltables.C
# rootWithPython310/doc/root/tutorials/sql/sqlcreatedb.py
# rootWithPython310/doc/root/tutorials/sql/SQLiteVersionsOfRoot.C
# rootWithPython310/doc/root/tutorials/sql/SQLitePlatformDistribution.C
# rootWithPython310/doc/root/tutorials/sql/runcatalog.sql
# rootWithPython310/doc/root/tutorials/r/
# rootWithPython310/doc/root/tutorials/r/DataFrame.C
# rootWithPython310/doc/root/tutorials/r/Integration.C
# rootWithPython310/doc/root/tutorials/r/SimpleFitting.C
# rootWithPython310/doc/root/tutorials/r/Minimization.C
# rootWithPython310/doc/root/tutorials/r/Function.C
# rootWithPython310/doc/root/tutorials/r/GlobalMinimization.C
# rootWithPython310/doc/root/tutorials/r/Functor.C
# rootWithPython310/doc/root/tutorials/r/Interpolation.C
# rootWithPython310/doc/root/tutorials/r/example.C
# rootWithPython310/doc/root/tutorials/pyroot/
# rootWithPython310/doc/root/tutorials/pyroot/pyroot001_arrayInterface.py
# rootWithPython310/doc/root/tutorials/pyroot/mrt.py
# rootWithPython310/doc/root/tutorials/pyroot/gui_ex.py
# rootWithPython310/doc/root/tutorials/pyroot/ratioplot.py
# rootWithPython310/doc/root/tutorials/pyroot/demo.py
# rootWithPython310/doc/root/tutorials/pyroot/pyroot004_NumbaDeclare.py
# rootWithPython310/doc/root/tutorials/pyroot/demoshelp.py
# rootWithPython310/doc/root/tutorials/pyroot/pyroot002_pythonizationDecorator.py
# rootWithPython310/doc/root/tutorials/pyroot/zdemo.py
# rootWithPython310/doc/root/tutorials/pyroot/tornado.py
# rootWithPython310/doc/root/tutorials/pyroot/ntuple1.py
# rootWithPython310/doc/root/tutorials/pyroot/shapes.py
# rootWithPython310/doc/root/tutorials/pyroot/na49view.py
# rootWithPython310/doc/root/tutorials/pyroot/pyroot006_tcontext_context_manager.py
# rootWithPython310/doc/root/tutorials/pyroot/na49visible.py
# rootWithPython310/doc/root/tutorials/pyroot/DynamicSlice.py
# rootWithPython310/doc/root/tutorials/pyroot/staff.py
# rootWithPython310/doc/root/tutorials/pyroot/fit1.py
# rootWithPython310/doc/root/tutorials/pyroot/parse_CSV_file_with_TTree_ReadStream.py
# rootWithPython310/doc/root/tutorials/pyroot/gerrors.py
# rootWithPython310/doc/root/tutorials/pyroot/hsum.py
# rootWithPython310/doc/root/tutorials/pyroot/surfaces.py
# rootWithPython310/doc/root/tutorials/pyroot/numberEntry.py
# rootWithPython310/doc/root/tutorials/pyroot/pyroot003_prettyPrinting.py
# rootWithPython310/doc/root/tutorials/pyroot/fillrandom.py
# rootWithPython310/doc/root/tutorials/pyroot/hsimple.py
# rootWithPython310/doc/root/tutorials/pyroot/fit1_py.py
# rootWithPython310/doc/root/tutorials/pyroot/pyroot005_tfile_context_manager.py
# rootWithPython310/doc/root/tutorials/pyroot/formula1.py
# rootWithPython310/doc/root/tutorials/pyroot/aptuple.txt
# rootWithPython310/doc/root/tutorials/pyroot/example_data.dat
# rootWithPython310/doc/root/tutorials/pyroot/na49geomfile.py
# rootWithPython310/doc/root/tutorials/pyroot/geometry.py
# rootWithPython310/doc/root/tutorials/pyroot/graph.py
# rootWithPython310/doc/root/tutorials/pyroot/h1ReadAndDraw.py
# rootWithPython310/doc/root/ReleaseNotes/
# rootWithPython310/doc/root/ReleaseNotes/old/
# rootWithPython310/doc/root/ReleaseNotes/old/ChangeLog-2-24
# rootWithPython310/doc/root/ReleaseNotes/v624/
# rootWithPython310/doc/root/ReleaseNotes/v624/index.md
# rootWithPython310/doc/root/ReleaseNotes/v610/
# rootWithPython310/doc/root/ReleaseNotes/v610/ReverseAxis.png
# rootWithPython310/doc/root/ReleaseNotes/v610/NewBoxOption.png
# rootWithPython310/doc/root/ReleaseNotes/v610/index.md
# rootWithPython310/doc/root/ReleaseNotes/v610/NewMarkers.png
# rootWithPython310/doc/root/ReleaseNotes/v612/
# rootWithPython310/doc/root/ReleaseNotes/v612/index.md
# rootWithPython310/doc/root/ReleaseNotes/v608/
# rootWithPython310/doc/root/ReleaseNotes/v608/index.md
# rootWithPython310/doc/root/ReleaseNotes/v620/
# rootWithPython310/doc/root/ReleaseNotes/v620/index.md
# rootWithPython310/doc/root/ReleaseNotes/v616/
# rootWithPython310/doc/root/ReleaseNotes/v616/index.md
# rootWithPython310/doc/root/ReleaseNotes/v618/
# rootWithPython310/doc/root/ReleaseNotes/v618/index.md
# rootWithPython310/doc/root/ReleaseNotes/v604/
# rootWithPython310/doc/root/ReleaseNotes/v604/palette_93.png
# rootWithPython310/doc/root/ReleaseNotes/v604/palette_107.png
# rootWithPython310/doc/root/ReleaseNotes/v604/nostackb.png
# rootWithPython310/doc/root/ReleaseNotes/v604/palette_96.png
# rootWithPython310/doc/root/ReleaseNotes/v604/palette_66.png
# rootWithPython310/doc/root/ReleaseNotes/v604/palette_90.png
# rootWithPython310/doc/root/ReleaseNotes/v604/palette_94.png
# rootWithPython310/doc/root/ReleaseNotes/v604/palette_55.png
# rootWithPython310/doc/root/ReleaseNotes/v604/palette_80.png
# rootWithPython310/doc/root/ReleaseNotes/v604/palette_76.png
# rootWithPython310/doc/root/ReleaseNotes/v604/palette_82.png
# rootWithPython310/doc/root/ReleaseNotes/v604/palette_101.png
# rootWithPython310/doc/root/ReleaseNotes/v604/palette_67.png
# rootWithPython310/doc/root/ReleaseNotes/v604/palette_102.png
# rootWithPython310/doc/root/ReleaseNotes/v604/palette_52.png
# rootWithPython310/doc/root/ReleaseNotes/v604/index.md
# rootWithPython310/doc/root/ReleaseNotes/v604/palette_110.png
# rootWithPython310/doc/root/ReleaseNotes/v604/palette_98.png
# rootWithPython310/doc/root/ReleaseNotes/v604/palette_79.png
# rootWithPython310/doc/root/ReleaseNotes/v604/palette_57.png
# rootWithPython310/doc/root/ReleaseNotes/v604/palette_105.png
# rootWithPython310/doc/root/ReleaseNotes/v604/palette_92.png
# rootWithPython310/doc/root/ReleaseNotes/v604/palette_83.png
# rootWithPython310/doc/root/ReleaseNotes/v604/palette_109.png
# rootWithPython310/doc/root/ReleaseNotes/v604/palette_64.png
# rootWithPython310/doc/root/ReleaseNotes/v604/palette_60.png
# rootWithPython310/doc/root/ReleaseNotes/v604/palette_71.png
# rootWithPython310/doc/root/ReleaseNotes/v604/palette_91.png
# rootWithPython310/doc/root/ReleaseNotes/v604/palette_99.png
# rootWithPython310/doc/root/ReleaseNotes/v604/palette_61.png
# rootWithPython310/doc/root/ReleaseNotes/v604/palette_70.png
# rootWithPython310/doc/root/ReleaseNotes/v604/palette_69.png
# rootWithPython310/doc/root/ReleaseNotes/v604/palette_65.png
# rootWithPython310/doc/root/ReleaseNotes/v604/palette_56.png
# rootWithPython310/doc/root/ReleaseNotes/v604/palette_84.png
# rootWithPython310/doc/root/ReleaseNotes/v604/palette_100.png
# rootWithPython310/doc/root/ReleaseNotes/v604/palette_68.png
# rootWithPython310/doc/root/ReleaseNotes/v604/palette_59.png
# rootWithPython310/doc/root/ReleaseNotes/v604/palette_58.png
# rootWithPython310/doc/root/ReleaseNotes/v604/palette_85.png
# rootWithPython310/doc/root/ReleaseNotes/v604/palette_51.png
# rootWithPython310/doc/root/ReleaseNotes/v604/palette_75.png
# rootWithPython310/doc/root/ReleaseNotes/v604/palette_88.png
# rootWithPython310/doc/root/ReleaseNotes/v604/palette_104.png
# rootWithPython310/doc/root/ReleaseNotes/v604/palette_63.png
# rootWithPython310/doc/root/ReleaseNotes/v604/palette_73.png
# rootWithPython310/doc/root/ReleaseNotes/v604/palette_74.png
# rootWithPython310/doc/root/ReleaseNotes/v604/palette_72.png
# rootWithPython310/doc/root/ReleaseNotes/v604/palette_108.png
# rootWithPython310/doc/root/ReleaseNotes/v604/palette_86.png
# rootWithPython310/doc/root/ReleaseNotes/v604/palette_78.png
# rootWithPython310/doc/root/ReleaseNotes/v604/colz0.png
# rootWithPython310/doc/root/ReleaseNotes/v604/palette_54.png
# rootWithPython310/doc/root/ReleaseNotes/v604/palette_103.png
# rootWithPython310/doc/root/ReleaseNotes/v604/palette_89.png
# rootWithPython310/doc/root/ReleaseNotes/v604/palette_81.png
# rootWithPython310/doc/root/ReleaseNotes/v604/palette_111.png
# rootWithPython310/doc/root/ReleaseNotes/v604/palette_87.png
# rootWithPython310/doc/root/ReleaseNotes/v604/palette_97.png
# rootWithPython310/doc/root/ReleaseNotes/v604/palette_62.png
# rootWithPython310/doc/root/ReleaseNotes/v604/palette_106.png
# rootWithPython310/doc/root/ReleaseNotes/v604/palette_77.png
# rootWithPython310/doc/root/ReleaseNotes/v604/palette_53.png
# rootWithPython310/doc/root/ReleaseNotes/v604/palette_95.png
# rootWithPython310/doc/root/ReleaseNotes/v628/
# rootWithPython310/doc/root/ReleaseNotes/v628/RooBrowser.png
# rootWithPython310/doc/root/ReleaseNotes/v628/index.md
# rootWithPython310/doc/root/ReleaseNotes/v628/TGraph2DAsymmErrors.png
# rootWithPython310/doc/root/ReleaseNotes/v614/
# rootWithPython310/doc/root/ReleaseNotes/v614/index.md
# rootWithPython310/doc/root/ReleaseNotes/v626/
# rootWithPython310/doc/root/ReleaseNotes/v626/index.md
# rootWithPython310/doc/root/ReleaseNotes/v622/
# rootWithPython310/doc/root/ReleaseNotes/v622/index.md
# rootWithPython310/doc/root/ReleaseNotes/v630/
# rootWithPython310/doc/root/ReleaseNotes/v630/index.md
# rootWithPython310/doc/root/ReleaseNotes/empty.md
# rootWithPython310/doc/root/ReleaseNotes/v606/
# rootWithPython310/doc/root/ReleaseNotes/v606/index.md
# rootWithPython310/doc/root/ReleaseNotes/v606/ttree_makeselector_option_examples.png
# rootWithPython310/doc/root/ReleaseNotes/v606/palette_112.png
# rootWithPython310/doc/root/LICENSE
# rootWithPython310/doc/root/INSTALL
# rootWithPython310/doc/root/cfortran.doc
# rootWithPython310/bin/
# rootWithPython310/bin/root-config
# rootWithPython310/bin/rootrm
# rootWithPython310/bin/rmkdepend
# rootWithPython310/bin/rootcp
# rootWithPython310/bin/rootmkdir
# rootWithPython310/bin/hist2workspace
# rootWithPython310/bin/rootmv
# rootWithPython310/bin/setxrd.csh
# rootWithPython310/bin/rootdrawtree
# rootWithPython310/bin/setxrd.sh
# rootWithPython310/bin/rootn.exe
# rootWithPython310/bin/rootssh
# rootWithPython310/bin/xpdtest
# rootWithPython310/bin/proofserv
# rootWithPython310/bin/rootslimtree
# rootWithPython310/bin/root
# rootWithPython310/bin/rootnb.exe
# rootWithPython310/bin/hadd
# rootWithPython310/bin/genreflex
# rootWithPython310/bin/rooteventselector
# rootWithPython310/bin/roots.exe
# rootWithPython310/bin/thisroot.csh
# rootWithPython310/bin/rootcint
# rootWithPython310/bin/rootcling
# rootWithPython310/bin/thisroot.fish
# rootWithPython310/bin/rootreadspeed
# rootWithPython310/bin/prepareHistFactory
# rootWithPython310/bin/root.exe
# rootWithPython310/bin/proofserv.exe
# rootWithPython310/bin/rootls
# rootWithPython310/bin/thisroot.sh
# rootWithPython310/bin/rootbrowse
# rootWithPython310/bin/rootprint
# rootWithPython310/bin/roots
# rootWithPython310/emacs/
# rootWithPython310/emacs/site-lisp/
# rootWithPython310/emacs/site-lisp/root-help.el
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# g++ is already the newest version (4:11.2.0-1ubuntu1).
# gcc is already the newest version (4:11.2.0-1ubuntu1).
# gfortran is already the newest version (4:11.2.0-1ubuntu1).
# libxext-dev is already the newest version (2:1.3.4-1build1).
# libxft-dev is already the newest version (2.3.4-1).
# binutils is already the newest version (2.38-4ubuntu2.2).
# cmake is already the newest version (3.22.1-1ubuntu1.22.04.1).
# dpkg-dev is already the newest version (1.21.1ubuntu2.2).
# git is already the newest version (1:2.34.1-1ubuntu1.9).
# libpython3.10-dev is already the newest version (3.10.6-1~22.04.2ubuntu1.1).
# libx11-dev is already the newest version (2:1.7.5-1ubuntu0.2).
# libxpm-dev is already the newest version (1:3.5.12-1ubuntu0.22.04.1).
# tar is already the newest version (1.34+dfsg-1ubuntu0.1.22.04.1).
# subversion is already the newest version (1.14.1-3ubuntu0.22.04.1).
# 0 upgraded, 0 newly installed, 0 to remove and 8 not upgraded.
# Welcome to JupyROOT 6.29/01

# %%
# !apt-get install libpython3-dev
import sys
sys.path.append("/content/content/rootWithPython310/")
sys.path.append("/content/content/rootWithPython310/bin/")
sys.path.append("/content/content/rootWithPython310/include/")
sys.path.append("/content/content/rootWithPython310/lib/")
import ctypes
ctypes.cdll.LoadLibrary('/content/content/rootWithPython310/lib/libCore.so')
ctypes.cdll.LoadLibrary('/content/content/rootWithPython310/lib/libThread.so')
ctypes.cdll.LoadLibrary('/content/content/rootWithPython310/lib/libTreePlayer.so')
import ROOT
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# libpython3-dev is already the newest version (3.10.6-1~22.04).
# 0 upgraded, 0 newly installed, 0 to remove and 8 not upgraded.

# %%
# !rm -rf /content/content
